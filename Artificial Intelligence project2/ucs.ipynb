# %%
#import libraries
from queue import Queue
import copy
import time
import tracemalloc

# %%
#Initialization
representMovesString = ["up" , "right" , "down" , "left"]
samples = []
easy_samples = []
medium_samples = []
hard_samples = []
count = 0
totalTimeForBfsSearch = 0
totalMemoryForBfsSearch = 0
totalNumberOfBfsSearch = 0

# %%
#read Example.txt file and Initialization
with open("Examples.txt") as fp:
    while True:
        count += 1
        line = fp.readline()
  
        if not line:
            break
        samples.append(line.strip())
        
for i in range(len(samples)):
    if(i>=1 and i<21):
        easy_samples.append(samples[i])
    elif(i>=23 and i<38):
        medium_samples.append(samples[i])
    elif(i>=41 and i<61):
        hard_samples.append((samples[i]))

for i in range(len(easy_samples)): 
    easy_samples[i]=easy_samples[i][2:]
    easy_samples[i]=easy_samples[i][:17]
    easy_samples[i]=easy_samples[i].split(",")
    easy_samples[i]=[[eval(easy_samples[i][0]),eval(easy_samples[i][1]),eval(easy_samples[i][2])],[eval(easy_samples[i][3]),eval(easy_samples[i][4]),eval(easy_samples[i][5])],[eval(easy_samples[i][6]),eval(easy_samples[i][7]),eval(easy_samples[i][8])],]
for i in range(len(medium_samples)): 
    medium_samples[i]=medium_samples[i][2:]
    medium_samples[i]=medium_samples[i][:17]
    medium_samples[i]=medium_samples[i].split(",")
    medium_samples[i]=[[eval(medium_samples[i][0]),eval(medium_samples[i][1]),eval(medium_samples[i][2])],[eval(medium_samples[i][3]),eval(medium_samples[i][4]),eval(medium_samples[i][5])],[eval(medium_samples[i][6]),eval(medium_samples[i][7]),eval(medium_samples[i][8])],]
for i in range(len(hard_samples)): 
    hard_samples[i]=hard_samples[i][2:]
    hard_samples[i]=hard_samples[i][:17]
    hard_samples[i]=hard_samples[i].split(",")
    hard_samples[i]=[[eval(hard_samples[i][0]),eval(hard_samples[i][1]),eval(hard_samples[i][2])],[eval(hard_samples[i][3]),eval(hard_samples[i][4]),eval(hard_samples[i][5])],[eval(hard_samples[i][6]),eval(hard_samples[i][7]),eval(hard_samples[i][8])],]

# %%
#methods

#this method does an move in maze
def conversionMaze(myMaze, current, move):
    i , j = current[0] , current[1]
    movedMaze = copy.deepcopy(myMaze)
    if move == 0 :
        movedMaze[i][j] = movedMaze[i-1][j]
        movedMaze[i-1][j] = 0
    if move == 1 :
        movedMaze[i][j] = movedMaze[i][j+1]
        movedMaze[i][j+1] = 0
    if move == 2 :
        movedMaze[i][j] = movedMaze[i+1][j]
        movedMaze[i+1][j] = 0
    if move == 3:
        movedMaze[i][j] = movedMaze[i][j-1]
        movedMaze[i][j-1] = 0
    return movedMaze

#this method find the zero in 9 numbers
def find_zero(maze):
    for i in range(3):
        for j in range(3):
            if maze[i][j]==0:
                return [i,j]
            
def legalMoves(current):
    i , j = current[0] , current[1]
    #l is a list of all  legal moves
    l = []
    if (i != 0):
        l.append(0)
    if (j != 2):
        l.append(1)
    if (i != 2):
        l.append(2)
    if (j != 0):
        l.append(3)
    return l

# %%
def bfs(maze):
    movesSequence = []
    q = Queue()
    q.put([maze, [5]])
    
    while(not q.empty()):
        #c is stand for current ma
        c = q.get()
        #myMaze is in actual curret maze
        myMaze = c[0]
        if myMaze == [[1,2,3],[4,5,6],[7,8,0]] :
            return c[1]
        movesSequence.append(myMaze)
        zeroPlace = find_zero(myMaze)

        moves = legalMoves(zeroPlace)
        for i in moves:
            updatedMaze = conversionMaze(myMaze,zeroPlace,i)
            if updatedMaze not in movesSequence:
                currentMoves = copy.deepcopy(c[1])
                currentMoves.append(i)
                q.put([updatedMaze,currentMoves])

# %%
#bfs for easy samples
print("for easy samples:  ")
for i in range(len(easy_samples)):
    displayMat = easy_samples[i]
    print("for puzzle: ",displayMat)
    
    #bottom two lines calculate the whole time and memory
    startAlgorithm = time.time()
    tracemalloc.start()
    
    movesSequence = bfs(easy_samples[i])
    
    totalTime = time.time() - startAlgorithm
    totalMemory = tracemalloc.get_traced_memory()[1]
    totalTimeForBfsSearch += totalTime
    totalMemoryForBfsSearch += totalMemory
    totalNumberOfBfsSearch += 1
    print("time : ", totalTime)
    print("memory : ", totalMemory)
    
    print("action sequence: ",end="")
    for i in range(1, len(movesSequence)):
        current_empty = find_zero(displayMat)
        if(i==len(movesSequence)-1):
            print(representMovesString[movesSequence[i]])
            print()
        else:
            print(representMovesString[movesSequence[i]],end="-")
        displayMat = conversionMaze(displayMat, current_empty, movesSequence[i])
# Out:
# for easy samples:
# for puzzle:  [[1, 2, 3], [0, 7, 6], [5, 4, 8]]
# time :  0.0370028018951416
# memory :  76823
# action sequence: right-down-left-up-right-down-right
#
# for puzzle:  [[0, 4, 1], [2, 5, 3], [7, 8, 6]]
# time :  0.12310338020324707
# memory :  230324
# action sequence: right-right-down-left-left-up-right-down-right-down
#
# for puzzle:  [[4, 1, 3], [0, 2, 6], [7, 5, 8]]
# time :  0.005000114440917969
# memory :  230324
# action sequence: up-right-down-down-right
#
# for puzzle:  [[1, 2, 3], [0, 4, 8], [7, 6, 5]]
# time :  0.033002614974975586
# memory :  230324
# action sequence: right-right-down-left-up-right-down
#
# for puzzle:  [[1, 2, 0], [4, 8, 3], [7, 6, 5]]
# time :  0.011001110076904297
# memory :  230324
# action sequence: down-down-left-up-right-down
#
# for puzzle:  [[1, 0, 2], [4, 6, 3], [7, 5, 8]]
# time :  0.0068874359130859375
# memory :  230324
# action sequence: right-down-left-down-right
#
# for puzzle:  [[0, 1, 2], [4, 5, 3], [7, 8, 6]]
# time :  0.00427699089050293
# memory :  230324
# action sequence: right-right-down-down
#
# for puzzle:  [[1, 2, 3], [0, 4, 5], [7, 8, 6]]
# time :  0.0025076866149902344
# memory :  230324
# action sequence: right-right-down
#
# for puzzle:  [[1, 2, 3], [4, 0, 5], [7, 8, 6]]
# time :  0.002000570297241211
# memory :  230324
# action sequence: right-down
#
# for puzzle:  [[1, 2, 3], [4, 5, 0], [7, 8, 6]]
# time :  0.0
# memory :  230324
# action sequence: down
#
# for puzzle:  [[0, 1, 3], [4, 2, 5], [7, 8, 6]]
# time :  0.004003763198852539
# memory :  230324
# action sequence: right-down-right-down
#
# for puzzle:  [[2, 3, 5], [1, 0, 4], [7, 8, 6]]
# time :  0.05800175666809082
# memory :  230324
# action sequence: right-up-left-left-down-right-right-down
#
# for puzzle:  [[1, 6, 2], [5, 3, 0], [4, 7, 8]]
# time :  0.1090097427368164
# memory :  230324
# action sequence: left-up-right-down-left-left-down-right-right
#
# for puzzle:  [[1, 8, 2], [0, 4, 3], [7, 6, 5]]
# time :  0.0845649242401123
# memory :  230324
# action sequence: right-up-right-down-down-left-up-right-down
#
# for puzzle:  [[2, 5, 3], [4, 1, 6], [0, 7, 8]]
# time :  0.03542733192443848
# memory :  230324
# action sequence: up-right-up-left-down-down-right-right
#
# for puzzle:  [[1, 2, 3], [4, 6, 8], [7, 5, 0]]
# time :  0.004003286361694336
# memory :  230324
# action sequence: up-left-down-right
#
# for puzzle:  [[1, 6, 2], [5, 7, 3], [0, 4, 8]]
# time :  0.21021580696105957
# memory :  282351
# action sequence: right-up-up-right-down-left-left-down-right-right
#
# for puzzle:  [[0, 4, 1], [5, 3, 2], [7, 8, 6]]
# time :  0.11916065216064453
# memory :  282351
# action sequence: right-right-down-left-left-up-right-right-down-down
#
# for puzzle:  [[0, 5, 2], [1, 8, 3], [4, 7, 6]]
# time :  0.05000162124633789
# memory :  282351
# action sequence: down-down-right-up-up-right-down-down
#
# for puzzle:  [[1, 2, 3], [0, 4, 6], [7, 5, 8]]
# time :  0.003000020980834961
# memory :  282351
# action sequence: right-down-right

# %%
#bfs for medium samples

print("for medium samples:  ")
for i in range(len(medium_samples)):
    displayMat = medium_samples[i]
    print("for puzzle: ",displayMat)
    
    #bottom two lines calculate the whole time and memory
    startAlgorithm = time.time()
    tracemalloc.start()
    
    movesSequence = bfs(medium_samples[i])
    
    totalTime = time.time() - startAlgorithm
    totalMemory = tracemalloc.get_traced_memory()[1]
    totalTimeForBfsSearch += totalTime
    totalMemoryForBfsSearch += totalMemory
    totalNumberOfBfsSearch += 1
    print("time : ", totalTime)
    print("memory : ", totalMemory)
    
    print("action sequence: ",end="")
    for i in range(1, len(movesSequence)):
        current_empty = find_zero(displayMat)
        if(i==len(movesSequence)-1):
            print(representMovesString[movesSequence[i]])
            print()
        else:
            print(representMovesString[movesSequence[i]],end="-")
        displayMat = conversionMaze(displayMat, current_empty, movesSequence[i])
# Out:
# for medium samples:
# for puzzle:  [[1, 3, 5], [7, 2, 6], [8, 0, 4]]
# time :  0.3752727508544922
# memory :  553954
# action sequence: right-up-up-left-down-down-left-up-right-right-down
#
# for puzzle:  [[4, 1, 2], [3, 0, 6], [5, 7, 8]]
# time :  1.117846965789795
# memory :  1157890
# action sequence: left-down-right-right-up-left-left-up-right-right-down-down
#
# for puzzle:  [[4, 3, 1], [0, 7, 2], [8, 5, 6]]
# time :  1.1988637447357178
# memory :  1274934
# action sequence: right-up-right-down-left-down-left-up-up-right-right-down-down
#
# for puzzle:  [[5, 2, 1], [4, 8, 3], [7, 6, 0]]
# time :  19.144986629486084
# memory :  5207038
# action sequence: left-up-up-right-down-down-left-left-up-up-right-down-left-down-right-right
#
# for puzzle:  [[2, 0, 8], [1, 3, 5], [4, 6, 7]]
# time :  7.205317735671997
# memory :  5207038
# action sequence: down-right-up-left-down-down-right-up-left-up-left-down-down-right-right
#
# for puzzle:  [[3, 5, 6], [1, 4, 8], [0, 7, 2]]
# time :  21.595283031463623
# memory :  5910286
# action sequence: right-right-up-up-left-left-down-right-down-right-up-up-left-down-right-down
#
# for puzzle:  [[1, 0, 2], [7, 5, 4], [8, 6, 3]]
# time :  0.28038907051086426
# memory :  5910286
# action sequence: down-right-down-left-left-up-right-up-right-down-down
#
# for puzzle:  [[5, 1, 8], [2, 7, 3], [4, 0, 6]]
# time :  41.94596314430237
# memory :  7684438
# action sequence: up-up-left-down-right-up-right-down-left-up-left-down-down-right-up-right-down
#
# for puzzle:  [[4, 3, 0], [6, 1, 8], [2, 7, 5]]
# time :  4.178232431411743
# memory :  7684438
# action sequence: left-down-left-down-right-right-up-left-left-up-right-down-down-right
#
# for puzzle:  [[2, 4, 3], [1, 6, 5], [8, 0, 7]]
# time :  258.63007616996765
# memory :  17317066
# action sequence: up-up-right-down-down-left-up-right-up-left-left-down-right-down-left-up-right-right-down
#
# for puzzle:  [[1, 2, 3], [6, 4, 5], [7, 8, 0]]
# time :  2.5058305263519287
# memory :  17317066
# action sequence: up-left-left-down-right-up-right-down-left-left-up-right-right-down
#
# for puzzle:  [[3, 1, 2], [4, 5, 6], [7, 8, 0]]
# time :  11.776039123535156
# memory :  17317066
# action sequence: up-up-left-left-down-right-up-right-down-left-left-up-right-right-down-down
#
# for puzzle:  [[1, 2, 3], [4, 8, 7], [6, 5, 0]]
# time :  2.2923531532287598
# memory :  17317066
# action sequence: up-left-down-left-up-right-down-right-up-left-left-down-right-right
#
# for puzzle:  [[1, 3, 2], [5, 4, 6], [7, 8, 0]]
# time :  92.49975657463074
# memory :  17317066
# action sequence: up-up-left-left-down-right-right-down-left-left-up-up-right-down-left-down-right-right
#
# for puzzle:  [[1, 4, 2], [6, 5, 8], [7, 3, 0]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-c914a7bf2fd0> in <module>
#      10     tracemalloc.start()
#      11
# ---> 12     movesSequence = bfs(medium_samples[i])
#      13
#      14     totalTime = time.time() - startAlgorithm
#
# <ipython-input-5-bbb3674f290f> in bfs(maze)
#      20                 currentMoves = copy.deepcopy(c[1])
#      21                 currentMoves.append(i)
# ---> 22                 q.put([updatedMaze,currentMoves])
#
# KeyboardInterrupt:

# %%
#bfs for hard samples
print("for hard samples:  ")
for i in range(len(hard_samples)):
    displayMat = hard_samples[i]
    print("for puzzle: ",displayMat)
    
    #bottom two lines calculate the whole time and memory
    startAlgorithm = time.time()
    tracemalloc.start()
    
    movesSequence = bfs(hard_samples[i])
    
    totalTime = time.time() - startAlgorithm
    totalMemory = tracemalloc.get_traced_memory()[1]
    totalTimeForBfsSearch += totalTime
    totalMemoryForBfsSearch += totalMemory
    totalNumberOfBfsSearch += 1
    print("time : ", totalTime)
    print("memory : ", totalMemory)
    
    print("action sequence: ",end="")
    for i in range(1, len(movesSequence)):
        current_empty = find_zero(displayMat)
        if(i==len(movesSequence)-1):
            print(representMovesString[movesSequence[i]])
            print()
        else:
            print(representMovesString[movesSequence[i]],end="-")
        displayMat = conversionMaze(displayMat, current_empty, movesSequence[i])

# %%
#avrege time and memory for bfs
print("time average: ", totalTimeForBfsSearch/totalNumberOfBfsSearch)
print("memory average: ", totalMemoryForBfsSearch/totalNumberOfBfsSearch)
